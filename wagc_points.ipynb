# %% [markdown]
# ## Initialize weighting factors

# %%
place = [
    1900,
    1600,
    1300,
    1100,
    900,
    700,
    600,
    500,
    400,
    300,
    200,
    150,
    100,
    100,
    100,
    100,
    50,
]
place_top = len(place) - 1

internet_points = [
    500,
    420,
    340,
    290,
    235,
    185,
    160,
    130,
    105,
    80,
    55,
    40,
    25,
    25,
    25,
    25,
    15    
]
internet_top = len(internet_points) - 1

participation = {
}

params = {
    'ann_depreciation' : 0.2,
    'rep_depreciation' : 8000,
    'membership'      : 100,
    'sa_champs'       : sa_champs,
    'internet'        : internet_points,
    'inet_max_tour'   : 2,
    'part_max_tot'    : 1000,
    'part_max_opp'    : 200,
    'part'            : {'t': 40, 'c': 20, 'i': 20}    
}

# %% [markdown]
# ## Define class player

# %%
from functools import reduce

class player:
    
    #initialize
    def __init__(self, name, lyom, open):
        
        #name
        self.name=name
        
        #last year of membership
        self.lyom=lyom
        
        #opening balance
        self.open=open
        
        #annual depreciation
        self.dep=int(-round(params['ann_depreciation']*self.open))
        
        #representative's depreciation
        self.rep=0
        
        #membership points
        self.mem=0
        
        #SA championship points
        self.place=0
        
        #internet championship points
        self.inet=0
        self.inet_list=[]
        
        #paticipation points
        self.part=0
        self.part_list=[]
        
        #closing balance
        self.close=0
        
    #get string representation
    def __str__(self):
        return self.name+','+self.lyom+','+str(self.open)+','\
        +str(self.dep)+','+str(self.rep)+','+str(self.mem)+','\
        +str(self.place)+','+str(self.inet)+','+str(self.part)+','+str(self.close)
    
    #compare
    def __lt__(self,other): #supposed to replace __cmp__ in python 3, doesn't seem to work
        return self.close < other.close
  
    
#     def __cmp__(self,other):
#         if self.close < other.close:
#             return -1
#         elif self.close == other.close:
#             return 0
#         else:
#             return 1
    
    #set last year of membership
    def set_lyom(self,lyom):
        self.lyom=lyom
        
    #is member?
    def is_mem(self):
        return self.lyom==data['year']
        
    #calculate membership points
    def calc_mem(self):
        self.mem=params['membership']
        
    #calculate representative's depreciation
    def calc_rep(self,s,n,p,t):
        self.rep = -int(min(round(1000*(n+2*float(s)/100)-1000*(float(t)-p)/(t-1)),params['rep_depreciation']))
        
    
    #calculate SA championship points
    def calc_place(self,pos=-1,tie=1):
        place = params['sa_champs']
        if self.is_mem():            
            if pos==-1:
                self.place=place[-1]                
            else:
                if pos+tie<=place_top:
                    shared=reduce(lambda x,y: x+y,place[pos:pos+tie])
                elif pos<place_top and top<=pos+tie:
                    shared=reduce(lambda x,y: x+y,place[pos:place_top])+(pos+tie-place_top)*place[-1]
                elif inet_top<=pos:
                    shared=tie*place[-1]
                self.place=int(round(float(shared)/tie))
                
    #calculate internet championship points
    def calc_inet(self,pos=-1,tie=1):
        inet = params['internet']
        if pos==-1 or not self.is_mem():
            self.inet_list.append(0)
        else:
            if pos==-1:
                self.inet_list.append(0)
            else:
                if pos+tie<=inet_top:
                    shared=reduce(lambda x,y: x+y,inet[pos:pos+tie])
                elif pos<inet_top and top<=pos+tie:
                    shared=reduce(lambda x,y: x+y,inet[pos:inet_top])+(pos+tie-inet_top)*inet[-1]
                elif inet_top<=pos:
                    shared=tie*inet[-1]
                self.inet_list.append(int(round(float(shared)/tie)))
                
            copy=[]
            for x in self.inet_list:
            	copy.append(x)
            copy.sort()
            copy.reverse()
            self.inet=reduce(lambda x,y: x+y,copy[0:params['inet_max_tour']])
        
    #calculate participation points
    def calc_part(self,date,opp,game_type):
        if self.is_mem():
            if game_type in ['t','c','i'] :#(type=='i' and opp.is_mem()):
                if len(self.part_list) == 0:
                    self.part_list.append([date,opp.name,game_type,\
                                           params['part'][game_type],\
                                           params['part'][game_type],\
                                           params['part'][game_type]]) #?
                else:
                    cum_tot = self.part_list[-1][-1]
                    found = 0
                    i = len(self.part_list)
                    while not found and i>0:
                        i = i-1 
                        if self.part_list[i][1] == opp.name:
                           found = 1
                    if found:
                        cum_opp = self.part_list[i][4]
                    else:
                        cum_opp = 0
                    
                    points = min(params['part_max_tot']-cum_tot,
                                 params['part_max_opp']-cum_opp,
                                 params['part'][game_type])    
                    
                    self.part_list.append([date,opp.name,game_type,points,cum_opp+points,cum_tot+points])
            
            self.part = self.part_list[-1][-1]
    
    #calculate closing balance
    def calc_close(self):
        self.close=max(self.open+self.dep+self.rep+self.mem+self.place+self.inet+self.part,0)
        
    #create report
    def report(self):
        lines=[]
        w1=40
        w2=5
        w=w1+w2
        lines.append('-'*w+'\n')
        lines.append(('WAGC points for '+self.name).ljust(w)+'\n')
        lines.append('-'*w+'\n')
        lines.append((str(data['year'])+' opening balance:').ljust(w1)+str(self.open).rjust(w2)+'\n')
        lines.append(('Annual depreciation:').ljust(w1)+str(self.dep).rjust(w2)+'\n')
        lines.append(('Representative\'s depreciation:').ljust(w1)+str(self.rep).rjust(w2)+'\n')
        lines.append(('Membership points:').ljust(w1)+str(self.mem).rjust(w2)+'\n')
        lines.append(('SA Championship points:').ljust(w1)+str(self.place).rjust(w2)+'\n')
        lines.append(('Internet Championship points:').ljust(w1)+str(self.inet).rjust(w2)+'\n')
        lines.append(('Participation points:').ljust(w1)+str(self.part).rjust(w2)+'\n')
        lines.append('-'*w+'\n')
        lines.append((str(data['year'])+' closing balance:').ljust(w1)+str(self.close).rjust(w2)+'\n')
        lines.append('-'*w+'\n')
        lines.append('\n')
        lines.append('\n')
        lines.append('\n')
                
        w1=40
        w2=5
        w=w1+w2
        lines.append('-'*w+'\n')
        lines.append('Exposition of Internet Championship points'.ljust(w)+'\n')
        lines.append('-'*w+'\n')
        for i in range(len(self.inet_list)):
            lines.append(('Tournament '+str(i+1)).ljust(w1)+str(self.inet_list[i]).rjust(w2)+'\n')
        lines.append('-'*w+'\n')
        lines.append(('Sum of '+str(params['inet_max_tour'])+' best results:').ljust(w1)+str(self.inet).rjust(w2)+'\n')
        lines.append('-'*w+'\n')
        lines.append('\n')
        lines.append('\n')
        lines.append('\n')
                
        w1=12
        w2=30
        w3=6
        w=w1+w2+w3*4
        lines.append('-'*w+'\n')
        lines.append('Exposition of participation points'.ljust(w)+'\n')
        lines.append('-'*w+'\n')
        lines.append(''.ljust(w1+w2)+'Game'.rjust(w3)+'Part'.rjust(w3)+'Cum'.rjust(w3)+'Cum'.rjust(w3)+'\n')
        lines.append('Date'.ljust(w1)+'Opponent'.ljust(w2)+'type'.rjust(w3)+'pnts'.rjust(w3)+\
                     'opp'.rjust(w3)+'tot'.rjust(w3)+'\n')
        lines.append('-'*w+'\n')
        for info in self.part_list:
            lines.append(info[0].ljust(w1)+info[1].ljust(w2)+info[2].rjust(w3)+str(info[3]).rjust(w3)+\
                         str(info[4]).rjust(w3)+str(info[5]).rjust(w3)+'\n')
        lines.append('-'*w+'\n')
        lines.append('\n')
        lines.append('\n')
        lines.append('\n')
        
        w=5
        lines.append('-'*w+'\n')
        lines.append('END'.center(w)+'\n')
        lines.append('-'*w+'\n')
        
        return lines

# %% [markdown]
# # Main
# Input

# %%
import pandas as pd

data = {
    'year'     : 2014,
    'open'     : pd.read_csv('open.txt',index_col=False),
    'rep'      : pd.read_csv('rep.txt',index_col=False,\
                             names=['name','sponsorship','times','placing','tot_participants']), #according to readme.txt
    'mem'      : open('mem.txt').readlines(),
    'place'    : open('place.txt').readlines(),
    'internet' : open('inet.txt').readlines(),
    'games'    : pd.read_csv('System_Games.csv',index_col=False,\
                             names=['date','black','white','handi','komi','diff','type','result','comment'])
}
players = {}

# %% [markdown]
# * initialize players with opening balances
# * calulate annual depreciation

# %%
for line in data['open'].iterrows():
    name = line[1]['Name'].strip()
    lyom = line[1]['Last year of membership']
    closing_balance = line[1][-1]    
    players[name] = player(name,lyom,closing_balance)
    print("%s:\t%s\t%s"%(name,players[name].lyom,players[name].open))
# Out:
# Victor Chow:	2013	10720
# Andre Connell:	2013	8813
# Welile Gogotshe:	2013	8579
# John Leuner:	2013	8293
# Samuel Scott:	2013	8262
# Andrew Davies:	2013	8254
# Lloyd Rubidge:	2013	6835
# Chris Welsh:	2013	6434
# Ben Gale:	2013	6058
# David Richfield:	2013	5382
# Steve Kroon:	2013	4881
# Konrad Scheffler:	2012	4544
# Paul Edwards:	2013	4474
# Francois van Niekerk:	2013	4415
# Dave Gale:	2013	4312
# Bob Gale:	2013	4238
# Paul Steyn:	2013	4238
# Rory Shea:	2013	3632
# Sipho Mampe:	2013	3068
# James Nicolson:	2013	2728
# Max Rabkin:	2013	2653
# Aki Zhou:	2013	2560
# Chris Visser:	2013	2339
# Stephen Martindale:	2013	2169
# Ben Bredenkamp:	2013	2094
# Thabiso Lemeke:	2013	1924
# Gordon Wells:	2011	1768
# Tristen Taylor:	2006	1637
# Marc Loon:	2013	1496
# Rory Beling:	2008	1448
# Reinhardt Messerschmidt:	2007	1355
# James Gelant:	2012	1329
# Arnold Wentzel:	2013	1317
# Florian Breuer:	2009	992
# Cheng Lai:	2006	934
# Leander Gaum:	2006	894
# Jaco Swanepoel:	2007	840
# Peter Charter:	2013	801
# Sakkie Buys:	2013	797
# Carle Joubert:	2009	744
# Andries Kruger:	2006	738
# Clint Smythe:	2009	734
# Pablo Casado:	2012	730
# Christina Auret:	2007	730
# Hugo van der Merwe:	2007	638
# Clive Hunt:	2013	602
# Gustav Bertram:	2013	579
# Jonathan Jones:	2008	572
# Kabelo Suping:	2007	568
# Daniel Wium:	2006	534
# Mike Blignaut:	2012	523
# Alan Thompson:	2009	517
# Dylan Farre:	2013	513
# Sello Leopeng:	2007	508
# Trevor Hill:	2008	503
# Riaan Swart:	2010	496
# Guillaume Binet:	2006	491
# Ashley Ross:	2009	468
# Antoine Dymond:	2013	452
# Markus Jager:	2004	429
# Fred Strauss:	2004	425
# Ntsikelelo Kedijang:	2005	418
# Alexander du Plessis:	2010	418
# Chris Herries:	2011	406
# Margot Smythe:	2013	400
# Boitumelo Mohulatsi:	2005	393
# Sally Gross:	2013	390
# Harvey Zhang:	2013	360
# Dirk du Plessis:	2004	347
# Nevar Angelo:	2011	342
# Ricardo Kaizer:	2007	298
# Dale Morris:	2003	298
# Burt Rabie:	2011	287
# Francois Luus:	2010	285
# Michael Ben-Yosef:	2010	280
# Andy Mantzios:	2008	274
# Fabio Costa:	2003	274
# Stuart Forsyth:	2006	270
# Ricky Pilane:	2007	265
# Zane Deane:	2007	264
# Richard Zhao:	2008	255
# Hanno Botha:	2006	251
# Itumeleng Motswiri:	2005	250
# Louis de Jager:	2006	230
# Brett Wilson:	2013	220
# Cornelia van der Walt:	2010	218
# John Stathakis:	2003	218
# Steven Dawson:	2006	190
# Nathi Gogotshe:	2005	168
# Emile Kraamwinkel:	2013	160
# Lucky Lekabe:	2005	158
# Wim Conradie:	2006	158
# Quintin Connell:	2008	155
# John Gilmore:	2009	150
# John Cass:	2010	147
# Paul Mantzios:	2003	146
# Mamiki Mohulatsi:	2005	145
# Jonah Sack:	2003	138
# Serdyn du Toit:	2006	134
# Iain Lawrie:	2006	134
# Brian Huma:	2007	131
# Tinus Cloete:	2011	128
# Marty Kintu:	2010	128
# Ruan van der Merwe:	2011	128
# Jean Llorca:	2004	126
# Andre Heydenrych:	2006	124
# David Lubinsky:	2003	122
# Gerrit Kapp:	2012	122
# Francis Parker:	2007	122
# Charles Levitt:	2003	116
# Mark Smith:	2013	100
# Candice Barker:	2010	98
# Geoff Marks:	2002	94
# Shuitao Fan:	2005	93
# Lu Descy:	2011	90
# Ramon Deane:	2007	89
# Thebego Suping:	2007	89
# John-Paul Harper:	2006	87
# Gareth Priede:	2004	84
# Timothy Twelves:	2003	78
# Bongane Sebogoe:	2007	78
# Lesego Setlhare:	2007	78
# Gustav Paul:	2011	77
# Richard Clark:	2005	74
# Hennie de Villiers:	2005	74
# Maurice Goodman:	2001	73
# Michael Frylinck:	2006	73
# Demian Walvisch:	2008	72
# Kgotso Dlamini:	2007	68
# Nhlanhla Shabangu:	2007	68
# Liesl Gini:	2006	67
# Alex Skelton:	2011	64
# Colin Phillips:	2011	64
# Vincent Maher:	2011	64
# Ishmael Suping:	2007	58
# Tembekile Sibuku:	2007	58
# Nhlanhla Mazibuko:	2007	58
# Kagiso Ceba:	2007	58
# Mandisi Majavu:	2009	58
# Tony Clulow:	2003	55
# Albert Ponelis:	2003	54
# Kallie Buys:	2002	52
# Ueli Gosteli:	2003	50
# Daniel Kotze:	2009	50
# Alex Siemers:	2006	48
# Timothy Spring:	2006	48
# Madito Mohulatsi:	2007	47
# Heinz Staschen:	2006	46
# Paul Harper:	2006	46
# Frans Lategan:	2005	45
# Tebogo Lekabe:	2001	43
# Lei Feng:	2006	42
# Andrew Clur:	2006	42
# Edwin Wes:	2003	42
# Andre Hartshorne:	2009	41
# Errol Burger:	2009	41
# Emil Wentzel:	2009	41
# Thoko Nodada:	2001	38
# Willie Krige:	2006	38
# BJ Brown:	2004	38
# Sabelo Moletsane:	2001	34
# Peter Brooks:	2008	33
# Joelus Officinale:	2008	33
# Mike-Alec Kearney:	2008	33
# Willem Bester:	2008	33
# Jan-Jan van der Vyver:	2008	33
# Ludwig Schwardt:	2005	29
# Refilwe Maputle:	2002	28
# Mariana Kapp:	2006	26
# Pieter Bezuidenhout:	2007	26
# JC van der Walt:	2007	26
# Chris Nortje:	2005	24
# Leon Wabeke:	2003	22
# Axel von Blottnitz:	2003	22
# Kevin Mattison:	2006	21
# Ernst Bekker:	2006	21
# Stefan Scriba:	2006	21
# Reinier Mostert:	2006	21
# Jacques Markram:	2006	21
# Tshepo Shole:	2002	21
# Karen Fourie:	2006	21
# Tony Putman:	2006	21
# Ben Ntuli:	2006	21
# Terry Webb:	2006	21
# Makhosini Mvelase:	2001	21
# Fred Senekal:	2006	21
# Lesego Mothlako:	2002	21
# Alan O'Regan:	2006	21
# Jan Gutter:	2003	19
# Clive Lai:	2005	17
# Rainier Joubert:	2005	17
# Schiefer:	2005	17
# Mark de Graeve:	2003	15
# Patrick Lee:	2003	11

# %% [markdown]
# calculate representative's depreciation

# %%
for line in data['rep'].iterrows():    
    name = line[1]['name']    
    
    if name in players.keys():
        s = line[1]['s']
        n = line[1]['n']
        p = line[1]['p']
        t = line[1]['t']
        players[name].calc_rep(s,n,p,t)
        print ("%s: \t%s"%(name,players[name].rep))
# Out:
# John Leuner: 	-2830
# Andre Connell: 	-2186

# %% [markdown]
# calculate membership points

# %%
for name in data['mem']:
    name = name.strip()
    
    if name in players.keys():
        players[name].set_lyom(data['year'])
    else:
        players[name] = player(name, data['year'], 0)
        
    players[name].calc_mem()
    
    print("%s:\t%s"%(name,players[name].mem))
# Out:
# Ben Bredenkamp:	100
# Peet Brits:	100
# Sakkie Buys:	100
# Peter Charter:	100
# Victor Chow:	100
# Andre Connell:	100
# Andrew Davies:	100
# Hendrik de Ridder:	100
# Antoine Dymond:	100
# Paul Edwards:	100
# Dylan Farre:	100
# Bob Gale:	100
# Ben Gale:	100
# Welile Gogotshe:	100
# Sally Gross:	100
# Brent Harrison:	100
# Clive Hunt:	100
# Gerrit Kapp:	100
# Kim He-Jin:	100
# Steve Kroon:	100
# John Leuner:	100
# Marc Loon:	100
# Christiaan Maasdorp:	100
# Elizabeth Meyer:	100
# James Nicolson:	100
# Lloyd Rubidge:	100
# Samuel Scott:	100
# Rory Shea:	100
# Allen Simpson:	100
# Margot Smythe:	100
# Paul Steyn:	100
# Jacobus van der Merwe:	100
# Francois van Niekerk:	100
# Chris Visser:	100
# Gordon Wells:	100
# Chris Welsh:	100
# Arnold Wentzel:	100
# Brett Wilson:	100
# Michael Yang:	100
# Harvey Zhang:	100
# Aki Zhou:	100

# %% [markdown]
# calculate SA championship points

# %%
pos = 0
qualified = True
qualifiers = []
others = []

for line in data['place']:
    if line.strip() == '*':
        qualified = False
    elif qualified:
        names = line.strip().split(',')        
        for name in names:
            if name in players.keys():                
                players[name].calc_place(pos,len(names))                                
                qualifiers.append(name)
                print('%s:\t%s'%(name,players[name].place))
        pos += len(names)
    elif not qualified:        
        others.append(line.strip()) 
print()
for name in (set(others) - set(qualifiers)):    
    if name in players.keys():            
        players[name].calc_place()    
        print('%s:\t%s'%(name,players[name].place))
# Out:
# Victor Chow:	1900
# Andre Connell:	1600
# Welile Gogotshe:	1300
# Samuel Scott:	1100
# John Leuner:	900
# Bob Gale:	700
# Andrew Davies:	600
# Chris Welsh:	500
# Paul Edwards:	400
# Lloyd Rubidge:	300
# James Nicolson:	200
# Ben Bredenkamp:	150
# Paul Steyn:	100
# Marc Loon:	100
# Peet Brits:	100
# Rory Shea:	100
#
# Ricardo Kaizer:	0
# Elizabeth Meyer:	50
# Christiaan Maasdorp:	50
# Margot Smythe:	50
# Brian Huma:	0
# Brett Wilson:	50
# Ricky Pilane:	0
# Allen Simpson:	50
# Zane Deane:	0

# %% [markdown]
# calculate internet championship points

# %%
pos = 0
participants = []

for line in data['internet']:
    if line.strip() == '*':
        for name in set(players.keys() - set(participants)):
            players[name].calc_inet()
            if players[name].inet > 0:
                print('%s:\t%s'%(name,players[name].inet))
        pos = 0
        participants = []
    else:
        names = line.split(',')
        for name in names:
            name = name.strip()
            if name in players.keys():
                players[name].calc_inet(pos,len(names))                
                if players[name].inet > 0:
                    print('%s:\t%s'%(name,players[name].inet))
                participants.append(name)
        pos += len(names)
# Out:
# Andrew Davies:	500
# Chris Welsh:	350
# John Leuner:	350
# Samuel Scott:	350
# Andre Connell:	193
# Paul Steyn:	193
# Rory Shea:	130
# Peet Brits:	105
# Hendrik de Ridder:	80
# Elizabeth Meyer:	55
# Andrew Davies:	1000
# Samuel Scott:	730
# Paul Steyn:	573
# John Leuner:	612
# Chris Welsh:	612
# Francois van Niekerk:	185
# Peet Brits:	265
# Christiaan Maasdorp:	130
# Elizabeth Meyer:	160
# Rory Shea:	210
# Andre Connell:	193
# Hendrik de Ridder:	80
# Andrew Davies:	1000
# John Leuner:	700
# Chris Welsh:	700
# Gordon Wells:	350
# Peet Brits:	353
# Hendrik de Ridder:	273
# Elizabeth Meyer:	298
# Andre Connell:	193
# Samuel Scott:	730
# Paul Steyn:	573
# Francois van Niekerk:	185
# Rory Shea:	210
# Christiaan Maasdorp:	130
# Andrew Davies:	1000
# Peet Brits:	573
# Christiaan Maasdorp:	392
# Rory Shea:	392
# Elizabeth Meyer:	365
# Chris Welsh:	700
# Andre Connell:	193
# Samuel Scott:	730
# Hendrik de Ridder:	273
# Gordon Wells:	350
# Paul Steyn:	573
# Francois van Niekerk:	185
# John Leuner:	700

# %% [markdown]
# calculate participation points

# %%
game_type = {0.5 : 'i', 1.0 : 'c', 1.5 : 't' , 0.0 : 'n'}
import datetime

for line in data['games'].iterrows():
    white = line[1]['white']
    black = line[1]['black']
    gt = game_type[line[1]['type']]
    newdate = datetime.datetime.strptime(line[1]['date'],'%d/%m/%Y').strftime('%Y%m%d')
    
    if white in players.keys():
        if black in players.keys():                        
            players[white].calc_part(newdate,players[black],gt)
        else:
            players[white].calc_part(newdate,player(black,'',0),gt)
    
    if black in players.keys():
        if white in players.keys():
            players[black].calc_part(newdate,players[white],gt)
        else:
            players[black].calc_part(newdate,player(white,'',0),gt)

for name in players.keys():
    part = players[name].part
    if part > 0:
        print ("%s:\t%s"%(name,part))
# Out:
# Elizabeth Meyer:	1000
# Peet Brits:	1000
# James Nicolson:	240
# Lloyd Rubidge:	740
# Andre Connell:	1000
# Ben Bredenkamp:	420
# Victor Chow:	280
# Paul Edwards:	120
# Samuel Scott:	980
# Welile Gogotshe:	460
# Gordon Wells:	360
# Chris Visser:	20
# Margot Smythe:	300
# Brett Wilson:	180
# Paul Steyn:	820
# Allen Simpson:	80
# Antoine Dymond:	520
# Andrew Davies:	1000
# Jacobus van der Merwe:	140
# John Leuner:	1000
# Francois van Niekerk:	120
# Marc Loon:	820
# Michael Yang:	80
# Rory Shea:	860
# Arnold Wentzel:	400
# Chris Welsh:	1000
# Bob Gale:	700
# Harvey Zhang:	200
# Christiaan Maasdorp:	440
# Hendrik de Ridder:	240
# Kim He-Jin:	180

# %% [markdown]
# calculate closing balances

# %%
for name in players.keys():
    players[name].calc_close()

# %% [markdown]
# sort players by closing balances

# %%
players_list=[]

for name in players.keys():
    players_list.append(players[name])

players_list.sort(key=lambda player: player.close)
players_list.reverse()

i = 1
for player in players_list:
    print ("%s:\t%s\t%s"%(i,player.close,player.name))
    i += 1
# Out:
# 1:	10856	Victor Chow
# 2:	9520	Samuel Scott
# 3:	9303	Andrew Davies
# 4:	8723	Welile Gogotshe
# 5:	7757	Andre Connell
# 6:	7447	Chris Welsh
# 7:	6608	Lloyd Rubidge
# 8:	6504	John Leuner
# 9:	4983	Paul Steyn
# 10:	4946	Ben Gale
# 11:	4890	Bob Gale
# 12:	4358	Rory Shea
# 13:	4306	David Richfield
# 14:	4199	Paul Edwards
# 15:	4005	Steve Kroon
# 16:	3937	Francois van Niekerk
# 17:	3635	Konrad Scheffler
# 18:	3450	Dave Gale
# 19:	2722	James Nicolson
# 20:	2454	Sipho Mampe
# 21:	2345	Ben Bredenkamp
# 22:	2224	Gordon Wells
# 23:	2217	Marc Loon
# 24:	2148	Aki Zhou
# 25:	2122	Max Rabkin
# 26:	1991	Chris Visser
# 27:	1773	Peet Brits
# 28:	1735	Stephen Martindale
# 29:	1554	Arnold Wentzel
# 30:	1539	Thabiso Lemeke
# 31:	1515	Elizabeth Meyer
# 32:	1310	Tristen Taylor
# 33:	1158	Rory Beling
# 34:	1084	Reinhardt Messerschmidt
# 35:	1063	James Gelant
# 36:	982	Christiaan Maasdorp
# 37:	982	Antoine Dymond
# 38:	794	Florian Breuer
# 39:	770	Margot Smythe
# 40:	747	Cheng Lai
# 41:	741	Peter Charter
# 42:	738	Sakkie Buys
# 43:	715	Leander Gaum
# 44:	672	Jaco Swanepoel
# 45:	613	Hendrik de Ridder
# 46:	595	Carle Joubert
# 47:	590	Andries Kruger
# 48:	588	Harvey Zhang
# 49:	587	Clint Smythe
# 50:	584	Christina Auret
# 51:	584	Pablo Casado
# 52:	582	Clive Hunt
# 53:	510	Hugo van der Merwe
# 54:	510	Dylan Farre
# 55:	506	Brett Wilson
# 56:	463	Gustav Bertram
# 57:	458	Jonathan Jones
# 58:	454	Kabelo Suping
# 59:	427	Daniel Wium
# 60:	418	Mike Blignaut
# 61:	414	Alan Thompson
# 62:	412	Sally Gross
# 63:	406	Sello Leopeng
# 64:	402	Trevor Hill
# 65:	397	Riaan Swart
# 66:	393	Guillaume Binet
# 67:	374	Ashley Ross
# 68:	343	Markus Jager
# 69:	340	Fred Strauss
# 70:	334	Ntsikelelo Kedijang
# 71:	334	Alexander du Plessis
# 72:	325	Chris Herries
# 73:	314	Boitumelo Mohulatsi
# 74:	280	Kim He-Jin
# 75:	278	Dirk du Plessis
# 76:	274	Nevar Angelo
# 77:	240	Jacobus van der Merwe
# 78:	238	Ricardo Kaizer
# 79:	238	Dale Morris
# 80:	230	Allen Simpson
# 81:	230	Burt Rabie
# 82:	228	Francois Luus
# 83:	224	Michael Ben-Yosef
# 84:	219	Andy Mantzios
# 85:	219	Fabio Costa
# 86:	216	Stuart Forsyth
# 87:	212	Ricky Pilane
# 88:	211	Zane Deane
# 89:	204	Richard Zhao
# 90:	201	Hanno Botha
# 91:	200	Itumeleng Motswiri
# 92:	198	Gerrit Kapp
# 93:	184	Louis de Jager
# 94:	180	Michael Yang
# 95:	174	Cornelia van der Walt
# 96:	174	John Stathakis
# 97:	152	Steven Dawson
# 98:	134	Nathi Gogotshe
# 99:	128	Emile Kraamwinkel
# 100:	126	Lucky Lekabe
# 101:	126	Wim Conradie
# 102:	124	Quintin Connell
# 103:	120	John Gilmore
# 104:	118	John Cass
# 105:	117	Paul Mantzios
# 106:	116	Mamiki Mohulatsi
# 107:	110	Jonah Sack
# 108:	107	Serdyn du Toit
# 109:	107	Iain Lawrie
# 110:	105	Brian Huma
# 111:	102	Ruan van der Merwe
# 112:	102	Tinus Cloete
# 113:	102	Marty Kintu
# 114:	101	Jean Llorca
# 115:	100	Brent Harrison
# 116:	99	Andre Heydenrych
# 117:	98	David Lubinsky
# 118:	98	Francis Parker
# 119:	93	Charles Levitt
# 120:	80	Mark Smith
# 121:	78	Candice Barker
# 122:	75	Geoff Marks
# 123:	74	Shuitao Fan
# 124:	72	Lu Descy
# 125:	71	Ramon Deane
# 126:	71	Thebego Suping
# 127:	70	John-Paul Harper
# 128:	67	Gareth Priede
# 129:	62	Timothy Twelves
# 130:	62	Gustav Paul
# 131:	62	Bongane Sebogoe
# 132:	62	Lesego Setlhare
# 133:	59	Hennie de Villiers
# 134:	59	Richard Clark
# 135:	58	Demian Walvisch
# 136:	58	Maurice Goodman
# 137:	58	Michael Frylinck
# 138:	54	Kgotso Dlamini
# 139:	54	Liesl Gini
# 140:	54	Nhlanhla Shabangu
# 141:	51	Colin Phillips
# 142:	51	Vincent Maher
# 143:	51	Alex Skelton
# 144:	46	Tembekile Sibuku
# 145:	46	Kagiso Ceba
# 146:	46	Nhlanhla Mazibuko
# 147:	46	Mandisi Majavu
# 148:	46	Ishmael Suping
# 149:	44	Tony Clulow
# 150:	43	Albert Ponelis
# 151:	42	Kallie Buys
# 152:	40	Daniel Kotze
# 153:	40	Ueli Gosteli
# 154:	38	Alex Siemers
# 155:	38	Madito Mohulatsi
# 156:	38	Timothy Spring
# 157:	37	Heinz Staschen
# 158:	37	Paul Harper
# 159:	36	Frans Lategan
# 160:	34	Lei Feng
# 161:	34	Andrew Clur
# 162:	34	Edwin Wes
# 163:	34	Tebogo Lekabe
# 164:	33	Emil Wentzel
# 165:	33	Andre Hartshorne
# 166:	33	Errol Burger
# 167:	30	Willie Krige
# 168:	30	Thoko Nodada
# 169:	30	BJ Brown
# 170:	27	Sabelo Moletsane
# 171:	26	Peter Brooks
# 172:	26	Jan-Jan van der Vyver
# 173:	26	Mike-Alec Kearney
# 174:	26	Willem Bester
# 175:	26	Joelus Officinale
# 176:	23	Ludwig Schwardt
# 177:	22	Refilwe Maputle
# 178:	21	Mariana Kapp
# 179:	21	Pieter Bezuidenhout
# 180:	21	JC van der Walt
# 181:	19	Chris Nortje
# 182:	18	Axel von Blottnitz
# 183:	18	Leon Wabeke
# 184:	17	Ernst Bekker
# 185:	17	Jacques Markram
# 186:	17	Karen Fourie
# 187:	17	Tony Putman
# 188:	17	Ben Ntuli
# 189:	17	Tshepo Shole
# 190:	17	Alan O'Regan
# 191:	17	Fred Senekal
# 192:	17	Kevin Mattison
# 193:	17	Reinier Mostert
# 194:	17	Stefan Scriba
# 195:	17	Terry Webb
# 196:	17	Makhosini Mvelase
# 197:	17	Lesego Mothlako
# 198:	15	Jan Gutter
# 199:	14	Rainier Joubert
# 200:	14	Clive Lai
# 201:	14	Schiefer
# 202:	12	Mark de Graeve
# 203:	9	Patrick Lee

# %% [markdown]
# Example report

# %%
players['Gordon Wells'].report()
# Out:
# ['---------------------------------------------\n',
#  'WAGC points for Gordon Wells                 \n',
#  '---------------------------------------------\n',
#  '2014 opening balance:                    1768\n',
#  'Annual depreciation:                     -354\n',
#  "Representative's depreciation:              0\n",
#  'Membership points:                        100\n',
#  'SA Championship points:                     0\n',
#  'Internet Championship points:             350\n',
#  'Participation points:                     360\n',
#  '---------------------------------------------\n',
#  '2014 closing balance:                    2224\n',
#  '---------------------------------------------\n',
#  '\n',
#  '\n',
#  '\n',
#  '---------------------------------------------\n',
#  'Exposition of Internet Championship points   \n',
#  '---------------------------------------------\n',
#  'Tournament 1                                0\n',
#  'Tournament 2                                0\n',
#  'Tournament 3                              350\n',
#  'Tournament 4                                0\n',
#  '---------------------------------------------\n',
#  'Sum of 2 best results:                    350\n',
#  '---------------------------------------------\n',
#  '\n',
#  '\n',
#  '\n',
#  '------------------------------------------------------------------\n',
#  'Exposition of participation points                                \n',
#  '------------------------------------------------------------------\n',
#  '                                            Game  Part   Cum   Cum\n',
#  'Date        Opponent                        type  pnts   opp   tot\n',
#  '------------------------------------------------------------------\n',
#  '20140122    Peet Brits                         c    20    20    20\n',
#  '20140401    Paul Steyn                         c    20    20    40\n',
#  '20140415    Andrew Davies                      c    20    20    60\n',
#  '20140506    Chris Welsh                        c    20    20    80\n',
#  '20140520    Lloyd Rubidge                      c    20    20   100\n',
#  '20140610    Rory Shea                          c    20    20   120\n',
#  '20140617    Andrew Davies                      c    20    40   140\n',
#  '20140903    Chris Welsh                        t    40    60   180\n',
#  '20140903    Peet Brits                         t    40    60   220\n',
#  '20140902    Paul Steyn                         c    20    40   240\n',
#  '20140916    Rory Shea                          c    20    40   260\n',
#  '20140916    Rory Shea                          c    20    60   280\n',
#  '20141007    Chris Welsh                        c    20    80   300\n',
#  '20141007    Trevor Hill                        c    20    20   320\n',
#  '20141028    Lloyd Rubidge                      c    20    40   340\n',
#  '20141125    Lloyd Rubidge                      c    20    60   360\n',
#  '------------------------------------------------------------------\n',
#  '\n',
#  '\n',
#  '\n',
#  '-----\n',
#  ' END \n',
#  '-----\n']
